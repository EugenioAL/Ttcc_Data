# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

pathDir = 'C:/Users/Staz/Downloads/ttcct2/Anonimizados'

calculoDir = pathDir + '/' + 'Calculo1'
mdDir = pathDir + '/' + 'MD'
icDir = pathDir + '/' + 'IC'
ttccDir = pathDir + '/' + 'ttcc'
sample = pathDir + '/sample.csv'

#-------------------------------------------------- CAlC --------------------------------------------------------

fileList = os.listdir(calculoDir)

calcFrame = pd.read_csv(sample,sep=';',encoding='latin-1')
for i in range(len(fileList)):
    dTemp = pd.read_csv(calculoDir +'/'+ fileList[i],sep=';',encoding='latin-1')
    calcFrame = pd.concat([calcFrame,dTemp],ignore_index=True)
    
calcFrame.head(30)
# Out:
#    ID_TURMA            DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0     85148  Reprovado por Freqüência        17    103925      IE08
# 1     85148                  Aprovado        17    106109      IE08
# 2     85148        Reprovado por Nota        17    105176      IE08
# 3     85148                  Aprovado        17    105168      IE08
# 4     85148  Reprovado por Freqüência        17    102504      IE08
# 5     85148                  Aprovado        17    106782      IE08
# 6     85148        Reprovado por Nota        17    106785      IE08
# 7     85148  Reprovado por Freqüência        17    103920      IE08
# 8     85148  Reprovado por Freqüência        17    105182      IE08
# 9     85148                  Aprovado        17    102499      IE08
# 10    85148        Reprovado por Nota        17    103293      IE08
# 11    85148        Reprovado por Nota        17    102501      IE08
# 12    85148        Reprovado por Nota        17    106112      IE08
# 13    85148                  Aprovado        17    103922      IE08
# 14    85148  Reprovado por Freqüência        17    104188      IE08
# 15    85148  Reprovado por Freqüência        17    105177      IE08
# 16    85148        Reprovado por Nota        17    105180      IE08
# 17    85148                  Aprovado        17    105167      IE08
# 18    85148        Reprovado por Nota        17    106809      IE08
# 19    85148        Reprovado por Nota        17    104130      IE08
# 20    85148        Reprovado por Nota        17    103927      IE08
# 21    85148        Reprovado por Nota        17    106784      IE08
# 22    85148                  Aprovado        17    102502      IE08
# 23    85148        Reprovado por Nota        17    103292      IE08
# 24    85148        Reprovado por Nota        17    105179      IE08
# 25    85148        Reprovado por Nota        17    106113      IE08
# 26    85148        Reprovado por Nota        17    103921      IE08
# 27    85148  Reprovado por Freqüência        17    106380      IE08
# 28    85148  Reprovado por Freqüência        17    102132      IE08
# 29    85148                  Aprovado        17    105174      IE08
#
#                NOME_CURSO COD_ATIV_CURRIC NOME_ATIV_CURRIC NOTA1 NUM_FALTAS1  \
# 0   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 1   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 2   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 3   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 4   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 5   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 6   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 7   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 8   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 9   Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 10  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 11  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 12  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 13  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 14  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 15  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 16  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 17  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 18  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 19  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 20  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 21  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 22  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 23  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 24  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 25  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 26  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 27  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 28  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
# 29  Ciência da Computação          IEM011        CALCULO I   NaN         NaN
#
#     ... NOTA6 NUM_FALTAS6 NOTA7 NUM_FALTAS7 MEDIA_FINAL  \
# 0   ...   NaN         NaN   NaN         NaN        0,22
# 1   ...   NaN         NaN   NaN         NaN        5,11
# 2   ...   NaN         NaN   NaN         NaN        0,67
# 3   ...   NaN         NaN   NaN         NaN        5,33
# 4   ...   NaN         NaN   NaN         NaN           0
# 5   ...   NaN         NaN   NaN         NaN        5,05
# 6   ...   NaN         NaN   NaN         NaN        0,67
# 7   ...   NaN         NaN   NaN         NaN           0
# 8   ...   NaN         NaN   NaN         NaN           0
# 9   ...   NaN         NaN   NaN         NaN        5,11
# 10  ...   NaN         NaN   NaN         NaN        0,89
# 11  ...   NaN         NaN   NaN         NaN        1,45
# 12  ...   NaN         NaN   NaN         NaN        0,22
# 13  ...   NaN         NaN   NaN         NaN        6,89
# 14  ...   NaN         NaN   NaN         NaN        0,22
# 15  ...   NaN         NaN   NaN         NaN           0
# 16  ...   NaN         NaN   NaN         NaN        0,22
# 17  ...   NaN         NaN   NaN         NaN        8,22
# 18  ...   NaN         NaN   NaN         NaN           0
# 19  ...   NaN         NaN   NaN         NaN           0
# 20  ...   NaN         NaN   NaN         NaN           0
# 21  ...   NaN         NaN   NaN         NaN           1
# 22  ...   NaN         NaN   NaN         NaN        5,17
# 23  ...   NaN         NaN   NaN         NaN        0,78
# 24  ...   NaN         NaN   NaN         NaN        1,22
# 25  ...   NaN         NaN   NaN         NaN        1,22
# 26  ...   NaN         NaN   NaN         NaN        0,45
# 27  ...   NaN         NaN   NaN         NaN         NaN
# 28  ...   NaN         NaN   NaN         NaN           0
# 29  ...   NaN         NaN   NaN         NaN        7,55
#
#             DESCR_SITUACAO_1   ANO DESCR_PERIODO SITUACAO_ITEM PERIODO_ITEM
# 0   Reprovado por Freqüência  2013   1° Semestre             3          201
# 1                   Aprovado  2013   1° Semestre             1          201
# 2         Reprovado por Nota  2013   1° Semestre             2          201
# 3                   Aprovado  2013   1° Semestre             1          201
# 4   Reprovado por Freqüência  2013   1° Semestre             3          201
# 5                   Aprovado  2013   1° Semestre             1          201
# 6         Reprovado por Nota  2013   1° Semestre             2          201
# 7   Reprovado por Freqüência  2013   1° Semestre             3          201
# 8   Reprovado por Freqüência  2013   1° Semestre             3          201
# 9                   Aprovado  2013   1° Semestre             1          201
# 10        Reprovado por Nota  2013   1° Semestre             2          201
# 11        Reprovado por Nota  2013   1° Semestre             2          201
# 12        Reprovado por Nota  2013   1° Semestre             2          201
# 13                  Aprovado  2013   1° Semestre             1          201
# 14  Reprovado por Freqüência  2013   1° Semestre             3          201
# 15  Reprovado por Freqüência  2013   1° Semestre             3          201
# 16        Reprovado por Nota  2013   1° Semestre             2          201
# 17                  Aprovado  2013   1° Semestre             1          201
# 18        Reprovado por Nota  2013   1° Semestre             2          201
# 19        Reprovado por Nota  2013   1° Semestre             2          201
# 20        Reprovado por Nota  2013   1° Semestre             2          201
# 21        Reprovado por Nota  2013   1° Semestre             2          201
# 22                  Aprovado  2013   1° Semestre             1          201
# 23        Reprovado por Nota  2013   1° Semestre             2          201
# 24        Reprovado por Nota  2013   1° Semestre             2          201
# 25        Reprovado por Nota  2013   1° Semestre             2          201
# 26        Reprovado por Nota  2013   1° Semestre             2          201
# 27  Reprovado por Freqüência  2013   1° Semestre             3          201
# 28  Reprovado por Freqüência  2013   1° Semestre             3          201
# 29                  Aprovado  2013   1° Semestre             1          201
#
# [30 rows x 28 columns]

# %%
fileList = os.listdir(icDir)

icFrame = pd.read_csv(sample,sep=';',encoding='latin-1')
for i in range(len(fileList)):
    dTemp = pd.read_csv(icDir +'/'+ fileList[i],sep=';',encoding='latin-1')
    icFrame = pd.concat([icFrame,dTemp],ignore_index=True)
     
icFrame.head(300)
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0      87196        Reprovado por Nota         1    103925      IE08
# 1      87196                  Aprovado         1    106109      IE08
# 2      87196                  Aprovado         1    105176      IE08
# 3      87196        Reprovado por Nota         1    105168      IE08
# 4      87196  Reprovado por Freqüência         1    102504      IE08
# ..       ...                       ...       ...       ...       ...
# 295   152236                  Aprovado      CB01    137185      IE08
# 296   152236  Reprovado por Freqüência      CB01    137974      IE08
# 297   167991                  Aprovado      CB01    147305      IE08
# 298   167991                  Aprovado      CB01    115440      IE08
# 299   167991                  Aprovado      CB01    147306      IE08
#
#                 NOME_CURSO COD_ATIV_CURRIC         NOME_ATIV_CURRIC NOTA1  \
# 0    Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 1    Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 2    Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 3    Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 4    Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# ..                     ...             ...                      ...   ...
# 295  Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 296  Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 297  Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 298  Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
# 299  Ciência da Computação          ICC001  INTRODUÇÃO À COMPUTAÇÃO   NaN
#
#     NUM_FALTAS1  ... NOTA6 NUM_FALTAS6 NOTA7 NUM_FALTAS7 MEDIA_FINAL  \
# 0           NaN  ...   NaN         NaN   NaN         NaN           0
# 1           NaN  ...   NaN         NaN   NaN         NaN        7,07
# 2           NaN  ...   NaN         NaN   NaN         NaN        5,02
# 3           NaN  ...   NaN         NaN   NaN         NaN        2,67
# 4           NaN  ...   NaN         NaN   NaN         NaN           0
# ..          ...  ...   ...         ...   ...         ...         ...
# 295         NaN  ...   NaN         NaN   NaN         NaN        9,56
# 296         NaN  ...   NaN         NaN   NaN         NaN        0,43
# 297         NaN  ...   NaN         NaN   NaN         NaN        8,78
# 298         NaN  ...   NaN         NaN   NaN         NaN        8,16
# 299         NaN  ...   NaN         NaN   NaN         NaN        8,86
#
#              DESCR_SITUACAO_1   ANO DESCR_PERIODO SITUACAO_ITEM PERIODO_ITEM
# 0          Reprovado por Nota  2013   1° Semestre             2          201
# 1                    Aprovado  2013   1° Semestre             1          201
# 2                    Aprovado  2013   1° Semestre             1          201
# 3          Reprovado por Nota  2013   1° Semestre             2          201
# 4    Reprovado por Freqüência  2013   1° Semestre             3          201
# ..                        ...   ...           ...           ...          ...
# 295                  Aprovado  2017   1° Semestre             1          201
# 296  Reprovado por Freqüência  2017   1° Semestre             3          201
# 297                  Aprovado  2018   1° Semestre             1          201
# 298                  Aprovado  2018   1° Semestre             1          201
# 299                  Aprovado  2018   1° Semestre             1          201
#
# [300 rows x 28 columns]

# %%
fileList = os.listdir(mdDir)

mdFrame = pd.read_csv(sample,sep=';',encoding='latin-1')
for i in range(len(fileList)):
    dTemp = pd.read_csv(mdDir +'/'+ fileList[i],sep=';',encoding='latin-1')
    mdFrame = pd.concat([mdFrame,dTemp],ignore_index=True)
     
mdFrame.head(300)
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0     137968                  Aprovado      CB01    130413      IE08
# 1     137968                  Aprovado      CB01    130406      IE08
# 2     137968  Reprovado por Freqüência      CB01    129393      IE08
# 3     137968                  Aprovado      CB01    130409      IE08
# 4     137968                  Aprovado      CB01    129247      IE08
# ..       ...                       ...       ...       ...       ...
# 269   216339                  Aprovado      CB01    164695      IE08
# 270   216339                  Aprovado      CB01    164697      IE08
# 271   216339                  Aprovado      CB01    163594      IE08
# 272   216339                  Aprovado      CB01    122058      IE08
# 273   216339                  Aprovado      CB01    162788      IE08
#
#                 NOME_CURSO COD_ATIV_CURRIC     NOME_ATIV_CURRIC NOTA1  \
# 0    Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 1    Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 2    Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 3    Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 4    Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# ..                     ...             ...                  ...   ...
# 269  Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 270  Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 271  Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 272  Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
# 273  Ciência da Computação          ICC120  MATEMÁTICA DISCRETA   NaN
#
#     NUM_FALTAS1  ... NOTA6 NUM_FALTAS6 NOTA7 NUM_FALTAS7 MEDIA_FINAL  \
# 0           NaN  ...   NaN         NaN   NaN         NaN        7,45
# 1           NaN  ...   NaN         NaN   NaN         NaN        5,06
# 2           NaN  ...   NaN         NaN   NaN         NaN           0
# 3           NaN  ...   NaN         NaN   NaN         NaN        6,15
# 4           NaN  ...   NaN         NaN   NaN         NaN        6,24
# ..          ...  ...   ...         ...   ...         ...         ...
# 269         NaN  ...   NaN         NaN   NaN         NaN         7,4
# 270         NaN  ...   NaN         NaN   NaN         NaN         7,5
# 271         NaN  ...   NaN         NaN   NaN         NaN        5,23
# 272         NaN  ...   NaN         NaN   NaN         NaN        5,07
# 273         NaN  ...   NaN         NaN   NaN         NaN         7,3
#
#              DESCR_SITUACAO_1   ANO DESCR_PERIODO SITUACAO_ITEM PERIODO_ITEM
# 0                    Aprovado  2016   1° Semestre             1          201
# 1                    Aprovado  2016   1° Semestre             1          201
# 2    Reprovado por Freqüência  2016   1° Semestre             3          201
# 3                    Aprovado  2016   1° Semestre             1          201
# 4                    Aprovado  2016   1° Semestre             1          201
# ..                        ...   ...           ...           ...          ...
# 269                  Aprovado  2020      Especial             1          401
# 270                  Aprovado  2020      Especial             1          401
# 271                  Aprovado  2020      Especial             1          401
# 272                  Aprovado  2020      Especial             1          401
# 273                  Aprovado  2020      Especial             1          401
#
# [274 rows x 28 columns]

# %%
fileList = os.listdir(ttccDir)

ttccFrame = pd.read_csv(sample,sep=';',encoding='latin-1')
for i in range(len(fileList)):
    dTemp = pd.read_csv(ttccDir +'/'+ fileList[i],sep=';',encoding='latin-1')
    ttccFrame = pd.concat([ttccFrame,dTemp],ignore_index=True)
     
ttccFrame.head(300)
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0      85151        Reprovado por Nota         1    103925      IE08
# 1      85151                  Aprovado         1    106109      IE08
# 2      85151                  Aprovado         1    105176      IE08
# 3      85151                  Aprovado         1    105168      IE08
# 4      85151  Reprovado por Freqüência         1    102504      IE08
# ..       ...                       ...       ...       ...       ...
# 295   167976        Reprovado por Nota      CB01    149327      IE08
# 296   167976  Reprovado por Freqüência      CB01    145634      IE08
# 297   167976        Reprovado por Nota      CB01    149439      IE08
# 298   167976  Reprovado por Freqüência      CB01    148363      IE08
# 299   167976  Reprovado por Freqüência      CB01    148609      IE08
#
#                 NOME_CURSO COD_ATIV_CURRIC  \
# 0    Ciência da Computação          ICC100
# 1    Ciência da Computação          ICC100
# 2    Ciência da Computação          ICC100
# 3    Ciência da Computação          ICC100
# 4    Ciência da Computação          ICC100
# ..                     ...             ...
# 295  Ciência da Computação          ICC110
# 296  Ciência da Computação          ICC110
# 297  Ciência da Computação          ICC110
# 298  Ciência da Computação          ICC110
# 299  Ciência da Computação          ICC110
#
#                              NOME_ATIV_CURRIC NOTA1 NUM_FALTAS1  ... NOTA6  \
# 0        FUNDAMENTOS DE CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 1        FUNDAMENTOS DE CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 2        FUNDAMENTOS DE CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 3        FUNDAMENTOS DE CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 4        FUNDAMENTOS DE CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# ..                                        ...   ...         ...  ...   ...
# 295  TEXTOS TÉCNICOS EM CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 296  TEXTOS TÉCNICOS EM CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 297  TEXTOS TÉCNICOS EM CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 298  TEXTOS TÉCNICOS EM CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
# 299  TEXTOS TÉCNICOS EM CIÊNCIA DA COMPUTAÇÃO   NaN         NaN  ...   NaN
#
#     NUM_FALTAS6 NOTA7 NUM_FALTAS7 MEDIA_FINAL          DESCR_SITUACAO_1   ANO  \
# 0           NaN   NaN         NaN        2,17        Reprovado por Nota  2013
# 1           NaN   NaN         NaN        7,42                  Aprovado  2013
# 2           NaN   NaN         NaN        7,42                  Aprovado  2013
# 3           NaN   NaN         NaN           8                  Aprovado  2013
# 4           NaN   NaN         NaN           0  Reprovado por Freqüência  2013
# ..          ...   ...         ...         ...                       ...   ...
# 295         NaN   NaN         NaN        1,91        Reprovado por Nota  2018
# 296         NaN   NaN         NaN        3,45  Reprovado por Freqüência  2018
# 297         NaN   NaN         NaN        2,12        Reprovado por Nota  2018
# 298         NaN   NaN         NaN        2,57  Reprovado por Freqüência  2018
# 299         NaN   NaN         NaN           0  Reprovado por Freqüência  2018
#
#     DESCR_PERIODO SITUACAO_ITEM PERIODO_ITEM
# 0     1° Semestre             2          201
# 1     1° Semestre             1          201
# 2     1° Semestre             1          201
# 3     1° Semestre             1          201
# 4     1° Semestre             3          201
# ..            ...           ...          ...
# 295   1° Semestre             2          201
# 296   1° Semestre             3          201
# 297   1° Semestre             2          201
# 298   1° Semestre             3          201
# 299   1° Semestre             3          201
#
# [300 rows x 28 columns]

# %%
anos = calcFrame['ANO'].unique()
aprov = []

print(sum(calcFrame['DESCR_SITUACAO'] == 'Aprovado'))
for x in range(len(anos)):
    aprov.append(sum(calcFrame['DESCR_SITUACAO'] == 'Aprovado' and calcFrame['ANO'] == str(anos[x])
print(anos)
print(aprov)
# Out:
# 261
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14992/290038688.py in <module>
#       4 print(sum(calcFrame['DESCR_SITUACAO'] == 'Aprovado'))
#       5 for x in range(len(anos)):
# ----> 6     aprov.append(sum(calcFrame['DESCR_SITUACAO'] == 'Aprovado' and calcFrame['ANO'] == anos[x]))
#       7 print(anos)
#       8 print(aprov)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(len(calcFrame))
print(sum(calcFrame['DESCR_SITUACAO'] == 'Aprovado'))
# Out:
# 507
# 261
